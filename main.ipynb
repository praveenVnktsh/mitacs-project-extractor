# %%
from ctypes import windll#only needed on windows to account for DPI Scaling 
user32 = windll.user32
user32.SetProcessDPIAware()
import os
import time
from PIL import Image
import io
from selenium import webdriver
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
chrome_options = webdriver.ChromeOptions()
#chrome_options.add_argument("--headless")  
prefs = {"download.default_directory" : os.getcwd()+"/data"}
chrome_options.add_experimental_option("prefs",prefs)
chrome_options.add_argument("headless")
driver = webdriver.Chrome(options=chrome_options)

# %%
driver.get('https://globalink.mitacs.ca/#/student/application/projects') #Goto the project page

# %%
print(driver.page_source)
# Out:
# ny vertex can be changed from unfilled to filled; 2. At no cost, the player can apply the filling rule. The Z-Game number of a graph, denoted Z(G), is the minimum number of tokens needed to guarantee that all vertices can be filled (this is sometimes referred to as the "zero forcing number" or "fast-mixed search number", and also called graph infection). There have been many variations on the Z-Game, the one which will be considered here is a q-analogue of zero forcing which introduces a new operation available to the player. This new operation allows the application of the filling rule on a smaller part of the graph. The Zq-Game number of a graph, denoted Zq(G), is the minimum number of tokens needed to guarantee that all vertices can be filled, regardless of how the oracle responds. It is known that these numbers are ordered increasingly, but explicit relationships are still unresolved. The goal here is to characterize the behavior of Zq for various classes of graphs and derive formulas for these parameters for trees and outerplanar graphs.</p>
#               </div>
#               <div _ngcontent-c8="" class="ui-grid-col-3" style="padding-top: 2px; vertical-align: top;">
#                 <span _ngcontent-c8="" style="font-weight: bold; font-size: 12px;">Faculty supervisor: &nbsp;</span>
#                 <span _ngcontent-c8="">Shaun</span>
#                 <span _ngcontent-c8="">Fallat</span>
#                 <br _ngcontent-c8="">
#                 <span _ngcontent-c8="" style="font-weight: bold; font-size: 12px;">Host Province:</span>
#                 <span _ngcontent-c8="">Saskatchewan</span>
#                 <br _ngcontent-c8="">
#                 <span _ngcontent-c8="" style="font-weight: bold; font-size: 12px;">Host University:</span>
#                 <span _ngcontent-c8="">University of Regina – Regina</span>
#                 <br _ngcontent-c8="">
#                 <span _ngcontent-c8="" style="font-weight: bold; font-size: 12px;">Language:</span>
#                 <span _ngcontent-c8="">English</span>
#                 <br _ngcontent-c8="">
#                 <span _ngcontent-c8="" style="font-weight: bold; font-size: 12px;">Preferred start date:</span>
#                 <span _ngcontent-c8="">2021-05-03 (yyyy-mm-dd)</span>
#                 <br _ngcontent-c8="">
#                 <button _ngcontent-c8="" class="projectTabButton ui-button ui-widget ui-state-default ui-corner-all ui-button-text-only" pbutton=""><span class="ui-button-text ui-clickable">View Detail</span></button>
#                 <br _ngcontent-c8="">
#                 <br _ngcontent-c8="">
#                 <!---->
#               </div>
#             </div>
#           </div>
#
#           <div _ngcontent-c8="" class="ui-g-12 ui-md-12 ng-star-inserted" style="">
#             <div _ngcontent-c8="" class="ui-grid-row" style="padding-bottom: 2px; font-weight:bold">
#               <p _ngcontent-c8="">Project ID 22056</p>
#               <p _ngcontent-c8="">Support for Development of a Decision Support Framework for Nutrient Management in Freshwaters</p>
#             </div>
#             <div _ngcontent-c8="" class="ui-grid-row" style="border-bottom:1px solid #D5D5D5;">
#               <div _ngcontent-c8="" class="ui-grid-col-9" style="padding-right:16px; padding-top: 2px; vertical-align: top; text-align: justify">
#                 <p _ngcontent-c8="">A DPSIR (Driving force, Pressure, State, Impact and Response) conceptual framework will lead to a better understanding of causal relationships in human-environmental systems.  This includes an analysis of driving forces (e.g. agricultural activities) leading to specific pressures (e.g. phosphorus inputs) to a change in the state of the water body (e.g. degraded water quality) to a final impact (e.g. eutrophication and harmful algal blooms). The basic data will include the costs of various watershed conservation measures versus the benefits of reduction of eutrophication, harmful algal blooms and nuisance algae.
#
# The research will construct scenarios around economic measures to simulate phosphorus (and nitrogen) management strategies. For each strategy, the scenarios will include information regarding the activity for specific locations, spatial scale, and timing and type of intervention. To account for uncertainties regarding future scenarios, the student will include a range of choices for short-term action as well a framework to guide future actions, allowing dynamic adaptation over time to meet changing circumstances. The results will ultimately benefit practitioner and seek their input on the design of decision-support tools, to address objectives from multiple stakeholders, and improve likelihood of agencies to implement monitoring systems to gauge the success of the actions and need for adjustments
# </p>
#               </div>
#               <div _ngcontent-c8="" class="ui-grid-col-3" style="padding-top: 2px; vertical-align: top;">
#                 <span _ngcontent-c8="" style="font-weight: bold; font-size: 12px;">Faculty supervisor: &nbsp;</span>
#                 <span _ngcontent-c8="">Gail</span>
#                 <span _ngcontent-c8="">Krantzberg</span>
#                 <br _ngcontent-c8="">
#                 <span _ngcontent-c8="" style="font-weight: bold; font-size: 12px;">Host Province:</span>
#                 <span _ngcontent-c8="">Ontario</span>
#                 <br _ngcontent-c8="">
#                 <span _ngcontent-c8="" style="font-weight: bold; font-size: 12px;">Host University:</span>
#                 <span _ngcontent-c8="">McMaster University – Hamilton</span>
#                 <br _ngcontent-c8="">
#                 <span _ngcontent-c8="" style="font-weight: bold; font-size: 12px;">Language:</span>
#                 <span _ngcontent-c8="">English</span>
#                 <br _ngcontent-c8="">
#                 <span _ngcontent-c8="" style="font-weight: bold; font-size: 12px;">Preferred start date:</span>
#                 <span _ngcontent-c8="">2021-06-15 (yyyy-mm-dd)</span>
#                 <br _ngcontent-c8="">
#                 <button _ngcontent-c8="" class="projectTabButton ui-button ui-widget ui-state-default ui-corner-all ui-button-text-only" pbutton=""><span class="ui-button-text ui-clickable">View Detail</span></button>
#                 <br _ngcontent-c8="">
#                 <br _ngcontent-c8="">
#                 <!---->
#               </div>
#             </div>
#           </div>
#
#           <div _ngcontent-c8="" class="ui-g-12 ui-md-12 ng-star-inserted" style="">
#             <div _ngcontent-c8="" class="ui-grid-row" style="padding-bottom: 2px; font-weight:bold">
#               <p _ngcontent-c8="">Project ID 22057</p>
#               <p _ngcontent-c8="">Overcoming governance challenges in the Great Lakes: resilience for nearshore waters of the Great Lakes and Canada. </p>
#             </div>
#             <div _ngcontent-c8="" class="ui-grid-row" style="border-bottom:1px solid #D5D5D5;">
#               <div _ngcontent-c8="" class="ui-grid-col-9" style="padding-right:16px; padding-top: 2px; vertical-align: top; text-align: justify">
#                 <p _ngcontent-c8="">The Great Lakes are a grouping of five lakes found in the Mid-east region of North America. As the lakes border on two major countries, governance presents a challenge. These governance challenges have resulted in a Great Lakes ecosystem that is vulnerable to numerous diffuse stressors such as nutrient enrichment, aquatic invasive species and climate change. The Great Lakes Water Quality Agreement was revised in 2012, where for the first time the Protocol included a focus on the nearshore waters of the Great Lakes and calls for the development of a nearshore framework. The Great Lakes Water Quality Protocol 2012 also calls for an assessment of progress in meeting the terms of the agreement every three years. Whilst there are many indicators to monitor and evaluate the environmental quality of the Great Lakes waters, the governance framework for the Great Lakes contains no governance indicators.  However, measurement and reporting of progress is required to meet the terms of the Agreement. This project will seek to address these needs.
# Governance indicators have the potential to offer the Great Lakes public and practitioners explanations behind different levels of performance in the most heavily polluted areas, or other nearshore communities that will be prioritized for action over the next few years. Governance indicators have the potential to diagnose governance gaps and highlight areas in need of further investigation, strengthening the ability for practitioners to take
# The candidate will research governance indicators in shared water bodies, to recommend approaches that enable practitioners to measure outcomes of governance experiments and improve over time by learning.
# This project will deliver new knowledge and a new suite of tools for practitioners to use, to measure their capacity to adapt their governance approaches to problem solving.
# </p>
#               </div>
#               <div _ngcontent-c8="" class="ui-grid-col-3" style="padding-top: 2px; vertical-align: top;">
#                 <span _ngcontent-c8="" style="font-weight: bold; font-size: 12px;">Faculty supervisor: &nbsp;</span>
#                 <span _ngcontent-c8="">Gail</span>
#                 <span _ngcontent-c8="">Krantzberg</span>
#                 <br _ngcontent-c8="">
#                 <span _ngcontent-c8="" style="font-weight: bold; font-size: 12px;">Host Province:</span>
#                 <span _ngcontent-c8="">Ontario</span>
#                 <br _ngcontent-c8="">
#                 <span _ngcontent-c8="" style="font-weight: bold; font-size: 12px;">Host University:</span>
#                 <span _ngcontent-c8="">McMaster University – Hamilton</span>
#                 <br _ngcontent-c8="">
#                 <span _ngcontent-c8="" style="font-weight: bold; font-size: 12px;">Language:</span>
#                 <span _ngcontent-c8="">English</span>
#                 <br _ngcontent-c8="">
#                 <span _ngcontent-c8="" style="font-weight: bold; font-size: 12px;">Preferred start date:</span>
#                 <span _ngcontent-c8="">2021-06-15 (yyyy-mm-dd)</span>
#                 <br _ngcontent-c8="">
#                 <button _ngcontent-c8="" class="projectTabButton ui-button ui-widget ui-state-default ui-corner-all ui-button-text-only" pbutton=""><span class="ui-button-text ui-clickable">View Detail</span></button>
#                 <br _ngcontent-c8="">
#                 <br _ngcontent-c8="">
#                 <!---->
#               </div>
#             </div>
#           </div>
#
#           <div _ngcontent-c8="" class="ui-g-12 ui-md-12 ng-star-inserted" style="">
#             <div _ngcontent-c8="" class="ui-grid-row" style="padding-bottom: 2px; font-weight:bold">
#               <p _ngcontent-c8="">Project ID 22059</p>
#               <p _ngcontent-c8="">Virtualizing Heritage Places for remote access</p>
#             </div>
#             <div _ngcontent-c8="" class="ui-grid-row" style="border-bottom:1px solid #D5D5D5;">
#               <div _ngcontent-c8="" class="ui-grid-col-9" style="padding-right:16px; padding-top: 2px; vertical-align: top; text-align: justify">
#                 <p _ngcontent-c8="">This project focuses on developing remote access kits for heritage sites across Canada in collaboration with Canada´s National trust. Given the impact of the COVID-19 pandemic, access to heritage places, such as sites, parks, and museums has been completely limited. The kits will allow to record sites and provide virtual access to potential visitors in lockdown or accessing from other parts of the country and overseas.
#
# Intern students will be supervised by senior and junior researchers at the Carleton Immersive Media Studio (CIMS). The task involves learning how to acquire information from heritage sites using digital technologies, such as 360 panoramic photography, photogrammetry and 3D Scanning. As well, as, learning how to create a digital narrative for virtual reality and possible augmented reality applications to showcase the site.
# Furthermore, the students will contribute to the development of a capacity-building program for site managers that will be using the kit to digitize information about the cultural resource.</p>
#               </div>
#               <div _ngcontent-c8="" class="ui-grid-col-3" style="padding-top: 2px; vertical-align: top;">
#                 <span _ngcontent-c8="" style="font-weight: bold; font-size: 12px;">Faculty supervisor: &nbsp;</span>
#                 <span _ngcontent-c8="">Mario</span>
#                 <span _ngcontent-c8="">Santana Quintero</span>
#                 <br _ngcontent-c8="">
#                 <span _ngcontent-c8="" style="font-weight: bold; font-size: 12px;">Host Province:</span>
#                 <span _ngcontent-c8="">Ontario</span>
#                 <br _ngcontent-c8="">
#                 <span _ngcontent-c8="" style="font-weight: bold; font-size: 12px;">Host University:</span>
#                 <span _ngcontent-c8="">Carleton University – Ottawa</span>
#                 <br _ngcontent-c8="">
#                 <span _ngcontent-c8="" style="font-weight: bold; font-size: 12px;">Language:</span>
#                 <span _ngcontent-c8="">English</span>
#                 <br _ngcontent-c8="">
#                 <span _ngcontent-c8="" style="font-weight: bold; font-size: 12px;">Preferred start date:</span>
#                 <span _ngcontent-c8="">2021-05-03 (yyyy-mm-dd)</span>
#                 <br _ngcontent-c8="">
#                 <button _ngcontent-c8="" class="projectTabButton ui-button ui-widget ui-state-default ui-corner-all ui-button-text-only" pbutton=""><span class="ui-button-text ui-clickable">View Detail</span></button>
#                 <br _ngcontent-c8="">
#                 <br _ngcontent-c8="">
#                 <!---->
#               </div>
#             </div>
#           </div>
#
#           <div _ngcontent-c8="" class="ui-g-12 ui-md-12 ng-star-inserted" style="">
#             <div _ngcontent-c8="" class="ui-grid-row" style="padding-bottom: 2px; font-weight:bold">
#               <p _ngcontent-c8="">Project ID 22060</p>
#               <p _ngcontent-c8="">Make it with Gold ! </p>
#             </div>
#             <div _ngcontent-c8="" class="ui-grid-row" style="border-bottom:1px solid #D5D5D5;">
#               <div _ngcontent-c8="" class="ui-grid-col-9" style="padding-right:16px; padding-top: 2px; vertical-align: top; text-align: justify">
#                 <p _ngcontent-c8="">The project will concern the use of gold catalysis for the synthesis of various heteroaromatic motifs frequently found in the structure of compounds relevant to the pharmaceutical and agrochemical industries. The general strategy involves the activation of a substrate possessing multiple alkyne and/or alkene moieties by a gold complex to generate in a sequential manner multiple C-C and C-Heteroatom bonds and to ultimately produce a polycyclic system. An example of such an approach has been described in a paper from our group published recently, see : Angew. Chem. Int. Ed. 2018, 57, 13603-13607.  </p>
#               </div>
#               <div _ngcontent-c8="" class="ui-grid-col-3" style="padding-top: 2px; vertical-align: top;">
#                 <span _ngcontent-c8="" style="font-weight: bold; font-size: 12px;">Faculty supervisor: &nbsp;</span>
#                 <span _ngcontent-c8="">Fabien</span>
#                 <span _ngcontent-c8="">Gagosz</span>
#                 <br _ngcontent-c8="">
#                 <span _ngcontent-c8="" style="font-weight: bold; font-size: 12px;">Host Province:</span>
#                 <span _ngcontent-c8="">Ontario</span>
#                 <br _ngcontent-c8="">
#                 <span _ngcontent-c8="" style="font-weight: bold; font-size: 12px;">Host University:</span>
#                 <span _ngcontent-c8="">University of Ottawa – Ottawa</span>
#                 <br _ngcontent-c8="">
#                 <span _ngcontent-c8="" style="font-weight: bold; font-size: 12px;">Language:</span>
#                 <span _ngcontent-c8="">French</span>
#                 <br _ngcontent-c8="">
#                 <span _ngcontent-c8="" style="font-weight: bold; font-size: 12px;">Preferred start date:</span>
#                 <span _ngcontent-c8="">2021-05-03 (yyyy-mm-dd)</span>
#                 <br _ngcontent-c8="">
#                 <button _ngcontent-c8="" class="projectTabButton ui-button ui-widget ui-state-default ui-corner-all ui-button-text-only" pbutton=""><span class="ui-button-text ui-clickable">View Detail</span></button>
#                 <br _ngcontent-c8="">
#                 <br _ngcontent-c8="">
#                 <!---->
#               </div>
#             </div>
#           </div>
#
#                     <!---->
#                 </div>
#             </div>
#             <!----><p-paginator styleclass="ui-paginator-bottom" class="ng-star-inserted" style="">
#         <!----><div class="ui-paginator-bottom ui-paginator ui-widget ui-widget-header ui-unselectable-text ui-helper-clearfix ng-star-inserted">
#             <!---->
#             <a class="ui-paginator-first ui-paginator-element ui-state-default ui-corner-all ui-state-disabled" href="#" tabindex="-1">
#                 <span class="fa fa-step-backward"></span>
#             </a>
#             <a class="ui-paginator-prev ui-paginator-element ui-state-default ui-corner-all ui-state-disabled" href="#" tabindex="-1">
#                 <span class="fa fa-backward"></span>
#             </a>
#             <span class="ui-paginator-pages">
#                 <!----><a class="ui-paginator-page ui-paginator-element ui-state-default ui-corner-all ui-state-active ng-star-inserted" href="#">1</a><a class="ui-paginator-page ui-paginator-element ui-state-default ui-corner-all ng-star-inserted" href="#" style="">2</a><a class="ui-paginator-page ui-paginator-element ui-state-default ui-corner-all ng-star-inserted" href="#" style="">3</a><a class="ui-paginator-page ui-paginator-element ui-state-default ui-corner-all ng-star-inserted" href="#" style="">4</a><a class="ui-paginator-page ui-paginator-element ui-state-default ui-corner-all ng-star-inserted" href="#" style="">5</a>
#             </span>
#             <a class="ui-paginator-next ui-paginator-element ui-state-default ui-corner-all" href="#" tabindex="0">
#                 <span class="fa fa-forward"></span>
#             </a>
#             <a class="ui-paginator-last ui-paginator-element ui-state-default ui-corner-all" href="#" tabindex="0">
#                 <span class="fa fa-step-forward"></span>
#             </a>
#             <!---->
#             <!---->
#         </div>
#     </p-paginator>
#             <!---->
#         </div>
#     </p-datagrid>
#
#                 </div>
#
#                 <!---->
#             </div>
#         </div>
#     </p-panel>
#   </fieldset>
# </div></app-student-application-project>
# </app-application></app-student>
#
#         </div>
# </div>
# </app-body>
# </div>
# <app-footer _ngcontent-c0="" _nghost-c3=""><div _ngcontent-c3="" class="footer-wrapper" style="background-color:grey">
#     <footer _ngcontent-c3="" class="footer">
#         <div _ngcontent-c3="" class="container">
#             <div _ngcontent-c3="" class="wrapper">
#                 <ul _ngcontent-c3="" class="menu">
#                     <li _ngcontent-c3=""><a _ngcontent-c3="" target="_blank" href="https://www.mitacs.ca/en/website-privacy-statement"><span _ngcontent-c3="" style="color: #858585">Privacy Statement</span></a></li>
#                 </ul>
#             </div>
#             <span _ngcontent-c3="" style="color: #858585">Version: 1.20.09.1b</span>
#         </div>
#     </footer>
# </div></app-footer>
# </app-root>
# <script type="text/javascript" src="inline.bundle.js"></script><script type="text/javascript" src="polyfills.bundle.js"></script><script type="text/javascript" src="styles.bundle.js"></script><script type="text/javascript" src="vendor.bundle.js"></script><script type="text/javascript" src="main.bundle.js"></script><div class="cdk-visually-hidden" aria-atomic="true" aria-live="polite"></div>
#
# </body></html>

# %%
import time
def nextPage():
    elements = driver.find_elements_by_xpath('//*[@id="ui-panel-1-content"]/div/p-datagrid/div/p-paginator[1]/div/a[3]')[0]
    elements.click()

# %%
def execone():
    elements = driver.find_elements_by_xpath("//div[contains(@class, 'ui-g-12') and contains(@class, 'ui-md-12') and contains(@class, 'ng-star-inserted')]")
    curPID = 0
    for element in elements:
        idName = element.find_elements_by_class_name('ui-grid-row')
        header = idName[0].text.split('\n')
        name = header[-1]
        name = name.replace(',',';')
        pid = header[0].split()[-1]
        curPID = pid
        description = idName[1].find_elements_by_class_name('ui-grid-col-9')[0].text

        description = description.replace(',',';')
        hostDetails = element.find_element_by_class_name('ui-grid-col-3').text.split('\n')
        # print(profs[0].text)
        prof = hostDetails[0].split(':')[-1].strip()
        prof = prof.replace(',',';')
        hostProvince = hostDetails[1].split(':')[-1].strip()
        hostProvince = hostProvince.replace(',',';')
        hostUniv = hostDetails[2].split(':')[-1].strip()
        hostUniv = hostUniv.replace(',',';')
        language = hostDetails[3].split(':')[-1].strip()
        language = language.replace(',',';')
        startDate=  hostDetails[4].split(':')[-1].strip().split('(')[0].strip()
        startDate = startDate.replace(',',';')
        writeFile.write(pid + ',' + name +',' + description + ',' + prof + ',' + hostProvince + ',' + hostUniv + ',' + language + ',' + startDate + '\n')
    print(s, len(elements), curPID)
    nextPage()

# %%
# element=driver.find_elements_by_xpath("//*[text()='Project ID']")
# elements = driver.find_elements_by_class_name('ui-g-12')

writeFile = open('E:/dev/py/visionBasedScraper/mitacsInfo1.csv', 'w',  encoding="utf-8")

# element = elements[0]
s = 0
while s <=271:
    s += 1
    # elements = driver.find_elements_by_xpath("//div[contains(@class, 'ui-blockui') and contains(@class, 'ui-widget-overlay')]")
    # print(len(elements))
    a = 1
    while a > 0:
        a = len(driver.find_elements_by_id('waitBox'))
        time.sleep(0.1)
        print('.',end = '')
    print()
    execone()
    # except:
    #     time.sleep(2)
    #     print('Failed, retrying')
    #     execone()
    # time.sleep(4)

writeFile.close()
# Out:
# .
# 1 10 22060
# ............
# 2 10 22071
# ................
# 3 10 22082
# .......
# 4 10 22093
# ...............
# 5 10 22103
# ........................................................
# 6 10 22113
# ........................
# 7 10 22124
# ....................
# 8 10 22137
# ...........................
# 9 10 22147
# ........................................
# 10 10 22157
# .....................
# 11 10 22167
# ........................
# 12 10 22178
# ........................
# 13 10 22188
# ......................
# 14 10 22200
# .................................
# 15 10 22211
# ..................................
# 16 10 22221
# ..........................
# 17 10 22233
# ....................
# 18 10 22244
# ............................
# 19 10 22254
# ......................
# 20 10 22264
# ......................
# 21 10 22275
# ......................
# 22 10 22286
# .........................
# 23 10 22297
# ...........................
# 24 10 22308
# .........................
# 25 10 22319
# .........................
# 26 10 22331
# ..............................
# 27 10 22343
# ..........................
# 28 10 22354
# ............................
# 29 10 22364
# ...........................
# 30 10 22374
# ...................................
# 31 10 22384
# ......................................
# 32 10 22396
# ......................
# 33 10 22406
# ............................
# 34 10 22416
# ...........................
# 35 10 22427
# .....................................
# 36 10 22437
# ....................................
# 37 10 22448
# .............................
# 38 10 22459
# ...................
# 39 10 22469
# ......................
# 40 10 22480
# ......................
# 41 10 22491
# ..........................
# 42 10 22502
# ....................
# 43 10 22512
# .....................
# 44 10 22523
# .........................
# 45 10 22534
# ....................................
# 46 10 22546
# ...........................
# 47 10 22556
# .............................
# 48 10 22566
# .............................
# 49 10 22577
# ............................
# 50 10 22587
# ...........................
# 51 10 22597
# ............................
# 52 10 22608
# ................................
# 53 10 22618
# .................................
# 54 10 22628
# ...........................
# 55 10 22642
# ...................
# 56 10 22652
# .........................
# 57 10 22662
# ...................................
# 58 10 22672
# .....................
# 59 10 22682
# ...................
# 60 10 22692
# ......................
# 61 10 22703
# ...........................
# 62 10 22717
# ..............................
# 63 10 22731
# ............................
# 64 10 22743
# ....................................
# 65 10 22753
# ..................................
# 66 10 22763
# ....................
# 67 10 22774
# .........................
# 68 10 22784
# ...........................
# 69 10 22795
# .............................
# 70 10 22805
# ............................
# 71 10 22815
# ......................................
# 72 10 22825
# ..............................
# 73 10 22835
# ......................
# 74 10 22845
# ...........................
# 75 10 22856
# .........................
# 76 10 22869
# ................
# 77 10 22879
# ....................
# 78 10 22892
# .................
# 79 10 22902
# ...........................
# 80 10 22912
# ...........................
# 81 10 22924
# ...........................
# 82 10 22934
# ......................................
# 83 10 22945
# ...........................
# 84 10 22955
# ....................
# 85 10 22970
# ............................
# 86 10 22982
# ..............................
# 87 10 22993
# ..............................
# 88 10 23004
# .........................
# 89 10 23016
# ...........................
# 90 10 23026
# ......................
# 91 10 23037
# ..........................
# 92 10 23049
# .................................
# 93 10 23060
# ...............................
# 94 10 23073
# .............................
# 95 10 23088
# ......................................
# 96 10 23098
# ..............................
# 97 10 23108
# ......................
# 98 10 23118
# ...........................
# 99 10 23128
# ...........................
# 100 10 23138
# .............................
# 101 10 23148
# ..............................
# 102 10 23159
# .....................................
# 103 10 23169
# ......................
# 104 10 23179
# ........................
# 105 10 23190
# .........................
# 106 10 23200
# ..................................
# 107 10 23211
# .............................
# 108 10 23221
# ...............................
# 109 10 23231
# ..................................
# 110 10 23241
# .............................
# 111 10 23258
# ...............................
# 112 10 23269
# ..............................
# 113 10 23279
# ...............................
# 114 10 23290
# ....................................
# 115 10 23309
# .......................
# 116 10 23320
# ....................
# 117 10 23332
# .................................
# 118 10 23343
# ............................................
# 119 10 23353
# .................................
# 120 10 23371
# ...................................
# 121 10 23384
# .......................
# 122 10 23394
# .................
# 123 10 23405
# ..............................
# 124 10 23415
# ........................
# 125 10 23425
# ............................
# 126 10 23436
# ........................
# 127 10 23447
# .........................
# 128 10 23457
# .....................
# 129 10 23468
# .......................
# 130 10 23480
# ...........................
# 131 10 23490
# .........................
# 132 10 23500
# .........................
# 133 10 23513
# ............................
# 134 10 23524
# .........................
# 135 10 23534
# ........................
# 136 10 23548
# ..........................................
# 137 10 23558
# .................
# 138 10 23568
# .................
# 139 10 23578
# .........................
# 140 10 23589
# ...................
# 141 10 23602
# .........................
# 142 10 23613
# ...........................
# 143 10 23624
# ...........................
# 144 10 23634
# .......................
# 145 10 23645
# ..............................
# 146 10 23655
# ................................
# 147 10 23667
# ...........................
# 148 10 23679
# ....................................
# 149 10 23691
# ..............................
# 150 10 23703
# ..................
# 151 10 23713
# ...........................
# 152 10 23726
# ...................................
# 153 10 23738
# .................................................
# 154 10 23751
# ....................................
# 155 10 23763
# .......................
# 156 10 23773
# ............................
# 157 10 23785
# .................................
# 158 10 23796
# ..............................
# 159 10 23808
# .....................................
# 160 10 23818
# .......................................
# 161 10 23828
# ............................
# 162 10 23842
# .....................
# 163 10 23856
# .......................
# 164 10 23871
# ...................
# 165 10 23882
# ....................
# 166 10 23893
# ........................
# 167 10 23905
# .........................
# 168 10 23916
# ..........................................
# 169 10 23928
# .................................
# 170 10 23939
# ...................
# 171 10 23949
# ...................
# 172 10 23960
# ......................
# 173 10 23971
# .............................
# 174 10 23981
# ...................................
# 175 10 23992
# ...........................
# 176 10 24002
# ...........................
# 177 10 24014
# ..........................
# 178 10 24025
# .............................
# 179 10 24040
# .............................
# 180 10 24053
# ......................................
# 181 10 24064
# ............................
# 182 10 24077
# ....................
# 183 10 24087
# .........
# 184 10 24097
# ......
# 185 10 24111
# ............
# 186 10 24122
# ...........
# 187 10 24132
# .........
# 188 10 24143
# .........
# 189 10 24153
# .......
# 190 10 24165
# .........
# 191 10 24176
# ..........
# 192 10 24186
# ......................
# 193 10 24196
# .........
# 194 10 24206
# ............
# 195 10 24218
# ............
# 196 10 24232
# ............
# 197 10 24242
# ............
# 198 10 24252
# ............
# 199 10 24262
# ...............
# 200 10 24273
# ............
# 201 10 24283
# ................
# 202 10 24296
# ............
# 203 10 24308
# ..........
# 204 10 24319
# .........
# 205 10 24331
# .................
# 206 10 24341
# .........
# 207 10 24351
# .........
# 208 10 24361
# ......
# 209 10 24372
# ............
# 210 10 24382
# .........
# 211 10 24394
# .........
# 212 10 24404
# .......
# 213 10 24414
# .........
# 214 10 24425
# ..........
# 215 10 24435
# ............
# 216 10 24448
# ............
# 217 10 24460
# .......
# 218 10 24471
# ..........
# 219 10 24483
# ........
# 220 10 24493
# .........
# 221 10 24504
# .........
# 222 10 24518
# ..........
# 223 10 24529
# .........
# 224 10 24539
# ..........
# 225 10 24549
# ...........
# 226 10 24562
# ...........
# 227 10 24574
# ..........
# 228 10 24589
# .........
# 229 10 24604
# ......
# 230 10 24615
# .........
# 231 10 24627
# ..........
# 232 10 24640
# .........
# 233 10 24650
# .......
# 234 10 24661
# ..........
# 235 10 24671
# .......
# 236 10 24683
# ..........
# 237 10 24693
# ..........
# 238 10 24703
# ..........
# 239 10 24716
# .........
# 240 10 24728
# .....................
# 241 10 24740
# ............
# 242 10 24753
# ..........
# 243 10 24764
# .........
# 244 10 24777
# .........
# 245 10 24790
# ..............
# 246 10 24801
# .........
# 247 10 24811
# ...........
# 248 10 24826
# ..........
# 249 10 24837
# ...............
# 250 10 24847
# ...........
# 251 10 24859
# .....................
# 252 10 24869
# ...............
# 253 10 24879
# .....................
# 254 10 24889
# ..............
# 255 10 24899
# ............
# 256 10 24911
# .............
# 257 10 24926
# ..................
# 258 10 24937
# ...................
# 259 10 24948
# .......................
# 260 10 24958
# ....................
# 261 10 24968
# ........................
# 262 10 24979
# .......................
# 263 10 24990
# ..................
# 264 10 25001
# .........................
# 265 10 25014
# ............................
# 266 10 25024
# ..................................
# 267 10 25050
# ...............................
# 268 6 25058
# .
# 269 6 25058
# .
# 270 6 25058
# .
# 271 6 25058
# .
# 272 6 25058
